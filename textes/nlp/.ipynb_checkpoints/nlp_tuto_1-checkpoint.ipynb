# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import matplotlib
from matplotlib import pyplot as plt
# import seaborn as sns
# %matplotlib inline

# %%
data_all = pd.read_csv("../datasources/jeuxvideos/meilleursjeuvideo.csv")

# %%
data_all.describe()
# Out:
#                      Jeux                                        Description  \
# count                 200                                                197
# unique                200                                                197
# top     Tearaway sur Vita  Dans The Legend of Zelda : The Wind Waker, vou...
# freq                    1                                                  1
#
#        Sortie   Test     Avis
# count     200    200      187
# unique    172      3       41
# top      1993  19/20  18.7/20
# freq        6    123       14

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(data_all)

# %%
X_train.describe()
# Out:
#                                                    Jeux  \
# count                                               150
# unique                                              150
# top     Divinity : Original Sin II - Definitive Edition
# freq                                                  1
#
#                                               Description Sortie   Test  \
# count                                                 147    150    150
# unique                                                147    132      3
# top     Dans le jeu de rôle Phantasy Star IV sur Conso...   1994  19/20
# freq                                                    1      5     91
#
#            Avis
# count       139
# unique       38
# top     18.7/20
# freq          9

# %%
X_test.describe()
# Out:
#                      Jeux                                        Description  \
# count                  50                                                 50
# unique                 50                                                 50
# top     Tearaway sur Vita  God of War est un jeu d'action mythologique su...
# freq                    1                                                  1
#
#        Sortie   Test     Avis
# count      50     50       48
# unique     45      2       28
# top      1993  19/20  18.4/20
# freq        3     32        5

# %%
X_train.head()
# Out:
#                       Jeux                                        Description  \
# 157    Red Dead Redemption  Red Dead Redemption est un jeu d'action en mon...
# 185                 Silver  Silver sur PC est un jeu de rôle à dominante d...
# 84   Metroid Prime sur NGC  Metroid Prime est un jeu d'action en vue à la ...
# 156                 Unreal  Unreal est un jeu de tir à la première personn...
# 59        Okami HD sur PS3  Okami HD est un jeu d'aventure et d'action sur...
#
#               Sortie   Test     Avis
# 157      21 mai 2010  18/20  18.3/20
# 185       Avril 1999  18/20  18.4/20
# 84      21 mars 2003  19/20  18.6/20
# 156      30 mai 1998  18/20  18.7/20
# 59   31 octobre 2012  19/20      NaN

# %%
[X_train['Test'].str.split('/')[i][0] for i in X_train['Test'].index]
# Out:
# ['18',
#  '18',
#  '19',
#  '18',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '18',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '18',
#  '19',
#  '18',
#  '18',
#  '19',
#  '19',
#  '18',
#  '19',
#  '19',
#  '18',
#  '19',
#  '19',
#  '18',
#  '18',
#  '19',
#  '19',
#  '18',
#  '19',
#  '19',
#  '20',
#  '18',
#  '19',
#  '18',
#  '19',
#  '19',
#  '18',
#  '18',
#  '19',
#  '18',
#  '19',
#  '18',
#  '19',
#  '19',
#  '19',
#  '19',
#  '18',
#  '19',
#  '19',
#  '19',
#  '19',
#  '18',
#  '20',
#  '19',
#  '19',
#  '19',
#  '18',
#  '18',
#  '19',
#  '18',
#  '18',
#  '19',
#  '19',
#  '18',
#  '19',
#  '19',
#  '19',
#  '19',
#  '18',
#  '19',
#  '19',
#  '20',
#  '19',
#  '19',
#  '18',
#  '18',
#  '18',
#  '18',
#  '19',
#  '19',
#  '19',
#  '18',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '18',
#  '19',
#  '18',
#  '19',
#  '18',
#  '18',
#  '19',
#  '19',
#  '18',
#  '18',
#  '19',
#  '19',
#  '19',
#  '18',
#  '19',
#  '18',
#  '18',
#  '19',
#  '19',
#  '19',
#  '19',
#  '18',
#  '18',
#  '18',
#  '19',
#  '18',
#  '19',
#  '19',
#  '19',
#  '19',
#  '18',
#  '19',
#  '18',
#  '19',
#  '18',
#  '19',
#  '18',
#  '18',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '18',
#  '18',
#  '18',
#  '19',
#  '18',
#  '18',
#  '19',
#  '18',
#  '18']

# %%
X_train.head()
# Out:
#                                        Jeux  \
# 139  Castlevania : Order of Ecclesia sur DS
# 192                 Dungeon Keeper 2 sur PC
# 175                 Divinity : Original Sin
# 187              Virtua Fighter 4 Evolution
# 5            Kingpin : Life of Crime sur PC
#
#                                            Description            Sortie  \
# 139  Dracula refait surface alors que le clan Belmo...  27 novembre 2008
# 192  Dungeon Keeper 2 est un jeu de stratégie sorti...      Juillet 1999
# 175  Jeu de rôle au tour par tour, Divinity : Origi...      30 juin 2014
# 187  Virtua Fighter 4 Evolution est un jeu de comba...      20 juin 2003
# 5    Kingpin : Life of Crime est un jeu de tir à la...         Août 1999
#
#       Test     Avis
# 139  18/20      NaN
# 192  18/20    18/20
# 175  18/20  16.8/20
# 187  18/20  16.4/20
# 5    19/20  17.5/20

# %%
X_train['Test'].str.split('/')[1][0]
# Out:
# '20'
