# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot

k = pd.DataFrame()
k['X'] = np.arange(5)+3
k['Y'] = [1, 3, 4, 8, 12]
k
# Out:
#    X   Y
# 0  3   1
# 1  4   3
# 2  5   4
# 3  6   8
# 4  7  12

# %%
pyplot.scatter(k['X'], k['Y'], s = 150, c = 'red', marker = '*', edgecolors = 'blue')

# %%
k.corr(method='pearson')
# Out:
#           X         Y
# X  1.000000  0.971751
# Y  0.971751  1.000000

# %% [markdown]
# ### Correlation non linéaire ...

# %%
k['Y'] = [1, 1, 3, 2, 4]
k
# Out:
#    X  Y
# 0  3  1
# 1  4  1
# 2  5  3
# 3  6  2
# 4  7  4

# %%
pyplot.scatter(k['X'], k['Y'], s = 150, c = 'red', marker = '*', edgecolors = 'blue')

# %%
k.corr(method='spearman')
# Out:
#           X         Y
# X  1.000000  0.872082
# Y  0.872082  1.000000

# %%
k.corr(method='kendall')
# Out:
#           X         Y
# X  1.000000  0.737865
# Y  0.737865  1.000000

# %%
k.corr(method='pearson')
# Out:
#           X         Y
# X  1.000000  0.848875
# Y  0.848875  1.000000

# %%
k['X'].corr(k['Y'])
# Out:
# 0.8488746876271654

# %% [markdown]
# ### Utilisons les données du Titanic

# %%
titanic = pd.read_csv("../datasources/titanic/train.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data = titanic.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], axis=1)
data.corr(method='spearman')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.034091  0.041010 -0.061161  0.001235
# Survived       -0.005007  1.000000 -0.339668 -0.052565  0.088879  0.138266
# Pclass         -0.034091 -0.339668  1.000000 -0.361666 -0.043019 -0.022801
# Age             0.041010 -0.052565 -0.361666  1.000000 -0.182061 -0.254212
# SibSp          -0.061161  0.088879 -0.043019 -0.182061  1.000000  0.450014
# Parch           0.001235  0.138266 -0.022801 -0.254212  0.450014  1.000000
# Fare           -0.013975  0.323736 -0.688032  0.135051  0.447113  0.410074
#
#                  Fare
# PassengerId -0.013975
# Survived     0.323736
# Pclass      -0.688032
# Age          0.135051
# SibSp        0.447113
# Parch        0.410074
# Fare         1.000000

# %%
data.corr(method='spearman').style.format("{:.2}").background_gradient(cmap=pyplot.get_cmap('coolwarm'))
# Cf. https://matplotlib.org/examples/color/colormaps_reference.html pour les codes couleurs
# Out:
# <style  type="text/css" >
#     #T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col1 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col2 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col4 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col6 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row1_col0 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row1_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row1_col3 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row1_col4 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row1_col5 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row1_col6 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row2_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row2_col4 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row2_col5 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row3_col0 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row3_col1 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row3_col2 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row3_col6 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row4_col1 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row4_col2 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row4_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row4_col5 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row4_col6 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row5_col0 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row5_col1 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row5_col2 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row5_col3 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row5_col4 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row5_col6 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row6_col0 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row6_col1 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row6_col3 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row6_col4 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row6_col5 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_e087c916_668e_11e9_9f8d_bb184e3fd613row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_e087c916_668e_11e9_9f8d_bb184e3fd613" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PassengerId</th>        <th class="col_heading level0 col1" >Survived</th>        <th class="col_heading level0 col2" >Pclass</th>        <th class="col_heading level0 col3" >Age</th>        <th class="col_heading level0 col4" >SibSp</th>        <th class="col_heading level0 col5" >Parch</th>        <th class="col_heading level0 col6" >Fare</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e087c916_668e_11e9_9f8d_bb184e3fd613level0_row0" class="row_heading level0 row0" >PassengerId</th>
#                         <td id="T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col1" class="data row0 col1" >-0.005</td>
#                         <td id="T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col2" class="data row0 col2" >-0.034</td>
#                         <td id="T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col3" class="data row0 col3" >0.041</td>
#                         <td id="T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col4" class="data row0 col4" >-0.061</td>
#                         <td id="T_e087c916_668e_11e9_9f8d_bb184e3fd613row0_col5" class="data row0 col5" >0.0012</td>
#                         <td id="T_e087c916_668e_11e9_9f8d_bb184e3fd613row0
