# %%
import pandas as pd
import matplotlib.pyplot as plt
# prenons seulement les 5 premières lignes du jeu de données
titanic = pd.read_csv("../datasources/titanic/train.csv")[:5]

# %%
titanic
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Premier tracé

# %%
plt.plot(titanic.Fare)

# %% [markdown]
# ## Ajout des libellés d'axes

# %%
plt.plot(titanic.Fare)
plt.ylabel('Prix des billets')
plt.xlabel('Passagers')
# Out:
# Text(0.5,0,'Passagers')

# %% [markdown]
# ## Affectation des données d'abscisse (N° de passager)

# %%
plt.plot(titanic.PassengerId, titanic.Fare)
plt.ylabel('Prix des billets')
plt.xlabel('Passagers')
# Out:
# Text(0,0.5,'Prix des billets')

# %% [markdown]
# ## Empilement de courbes

# %%
plt.plot(titanic.PassengerId, titanic.Fare)
plt.plot(titanic.PassengerId, titanic.Survived)
plt.plot(titanic.PassengerId, titanic.Age)
plt.ylabel('Prix des billets')
plt.xlabel('Passagers')
# Out:
# Text(0,0.5,'Prix des billets')

# %% [markdown]
# ## Aspect des courbes

# %% [markdown]
# Codes des Courbes : **- ou -- ou -.  **
# Codes des couleurs : **b g r c m y k w**
# Largeur des traits avec **linewidth**

# %%
plt.plot(titanic.PassengerId, titanic.Fare, "k-.", linewidth=5)
plt.plot(titanic.PassengerId, titanic.Survived, "r", linewidth=1)
plt.plot(titanic.PassengerId, titanic.Age, "c", linewidth=10)
plt.ylabel('Prix des billets')
plt.xlabel('Passagers')
# Out:
# Text(0,0.5,'Prix des billets')

# %% [markdown]
# ## Ajouter une grille

# %%
plt.grid(True)
plt.plot(titanic.PassengerId, titanic.Fare, "k-.", linewidth=5)
plt.plot(titanic.PassengerId, titanic.Survived, "r", linewidth=1)
plt.plot(titanic.PassengerId, titanic.Age, "c", linewidth=10)
plt.ylabel('Prix des billets')
plt.xlabel('Passagers')
# Out:
# Text(0,0.5,'Prix des billets')

# %% [markdown]
# ## Marquer des points

# %%
plt.grid(True)
plt.plot(titanic.PassengerId, titanic.Fare, "k-.", linewidth=5)
plt.plot(titanic.PassengerId, titanic.Survived, "r", linewidth=1)
plt.plot(titanic.PassengerId, titanic.Age, "c", linewidth=10)
plt.ylabel('Prix des billets')
plt.xlabel('Passagers')
plt.text(2,70, '  Prix max !')
# Out:
# Text(2,70,'  Prix max !')

# %% [markdown]
# ## Ajouter une légende

# %%
plt.grid(True)
plt.plot(titanic.PassengerId, titanic.Fare, "k-.", linewidth=5)
plt.plot(titanic.PassengerId, titanic.Survived, "r", linewidth=1)
plt.plot(titanic.PassengerId, titanic.Age, "c", linewidth=10)
plt.ylabel('Prix des billets')
plt.xlabel('Passagers')
plt.text(2,70, '  Prix max !')
plt.legend()

# %% [markdown]
# ## Afficher plusieurs graphes

# %% [markdown]
# Par graphique il faut ajouter auparavant la commande subplot qui prend plusieurs arguments :
#     1) nombre de lignes de la graille de graphe
#     2) Nombre de colonnes de la graille de graphe
#     3) Index du graphe dans la grille
#     4) Options (ici on a précisé une couleur de fond)

# %%
plt.subplot(1, 2, 1)
plt.plot(titanic.PassengerId, titanic.Fare, "k-.", linewidth=5)
plt.subplot(1, 2, 2, facecolor='y')
plt.plot(titanic.PassengerId, titanic.Age, "c", linewidth=10)
