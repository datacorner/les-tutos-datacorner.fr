# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
from pytesseract import Output
import cv2

# %% [markdown]
# En cas d'erreur à ce niveau il faut peut être préciser ou se trouve l'exe tesseract :
# 'pytesseract.pytesseract.tesseract_cmd = r'<full_path_to_your_tesseract_executable>'

# %% [markdown]
# # Article 1 / datacorner.fr

# %%
pytesseract.get_tesseract_version()
# Out:
# LooseVersion ('4.0.0-beta.1')

# %%
simage1 = r'/home/benoit/git/python_tutos/tesseract/image_1.png'
image1 = Image.open(simage1)
image2 = Image.open(r'/home/benoit/git/python_tutos/tesseract/image_2.png')
type(image2)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
pytesseract.image_to_string(image1)
# Out:
# 'Ceci est un premier test'

# %%
pytesseract.image_to_string(image1, lang='fra')
# Out:
# 'Ceci est un premier test'

# %%
print(pytesseract.image_to_string(Image.open('/home/benoit/git/python_tutos/tesseract/image_2.png')))
# Out:
# Ceci est un premier test
#
# Avec un second texte

# %%
print(pytesseract.image_to_boxes(image1))
# Out:
# C 469 574 493 621 0
# e 493 574 505 621 0
# c 527 574 564 610 0
# i 586 575 591 622 0
# e 621 574 652 610 0
# s 659 574 683 610 0
# t 689 575 710 619 0
# u 737 574 764 609 0
# n 776 575 804 610 0
# p 835 562 861 610 0
# r 874 575 892 610 0
# e 896 574 924 610 0
# m 924 574 927 610 0
# i 955 575 985 610 0
# e 996 575 1001 622 0
# r 1017 574 1042 610 0
# t 1051 575 1105 619 0
# e 1118 574 1136 610 0
# s 1136 574 1149 610 0
# t 1164 574 1207 619 0

# %%
print(pytesseract.image_to_data(image1))
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	1920	1080	-1
# 2	1	1	0	0	0	469	458	738	60	-1
# 3	1	1	1	0	0	469	458	738	60	-1
# 4	1	1	1	1	0	469	458	738	60	-1
# 5	1	1	1	1	1	469	458	122	48	96	Ceci
# 5	1	1	1	1	2	621	461	89	45	95	est
# 5	1	1	1	1	3	737	470	67	36	95	un
# 5	1	1	1	1	4	835	458	207	60	96	premier
# 5	1	1	1	1	5	1051	461	156	45	96	test

# %%
print(pytesseract.image_to_osd(image2))
# Out:
# Page number: 0
# Orientation in degrees: 0
# Rotate: 0
# Orientation confidence: 2.01
# Script: Latin
# Script confidence: 11.11

# %%
print(pytesseract.image_to_pdf_or_hocr(image2))
# Out:
# b'%PDF-1.5\n%\xde\xad\xbe\xeb\n1 0 obj\n<<\n  /Type /Catalog\n  /Pages 2 0 R\n>>\nendobj\n3 0 obj\n<<\n  /BaseFont /GlyphLessFont\n  /DescendantFonts [ 4 0 R ]\n  /Encoding /Identity-H\n  /Subtype /Type0\n  /ToUnicode 6 0 R\n  /Type /Font\n>>\nendobj\n4 0 obj\n<<\n  /BaseFont /GlyphLessFont\n  /CIDToGIDMap 5 0 R\n  /CIDSystemInfo\n  <<\n     /Ordering (Identity)\n     /Registry (Adobe)\n     /Supplement 0\n  >>\n  /FontDescriptor 7 0 R\n  /Subtype /CIDFontType2\n  /Type /Font\n  /DW 500\n>>\nendobj\n5 0 obj\n<<\n  /Length 210 /Filter /FlateDecode\n>>\nstream\nx\x9c\xec\xc2\x01\t\x00\x00\x00\x02\xa0\xfa\x7f\xba!\x89\xa6\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80{\x03\x00\x00\xff\xff\xec\xc2\x01\r\x00\x00\x00\xc2 \xdf\xbf\xb4E\x18\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xeb\x00\x00\x00\xff\xff\xec\xc2\x01\r\x00\x00\
# ...
